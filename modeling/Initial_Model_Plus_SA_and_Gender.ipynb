# %%
# questions I have as I think about this more:
# when we do the whole deduplication, we should only be doing that on TRAIN, right?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import HashingVectorizer, CountVectorizer
from scipy.sparse import hstack, vstack, csr_matrix
import pandas as pd
import numpy as np
import copy
import time
import pickle
import os

pd.set_option('max_colwidth', 100)

# %%
splits = "splits_1571429760//"

# %%
data_folder = "data//"
train_path = data_folder + splits + "train.csv"
dev_path = data_folder + splits + "dev.csv"

# %%
this_model_folder = "unigram_with_sa_and_responder//"
models_folder = "models//"
pkl_filename = models_folder + this_model_folder + "model.pkl"
vectorizer_filename = models_folder + this_model_folder + "vectorizer.pkl"

# %%
train_df = pd.read_csv(train_path, index_col=0)

# %%
first_sa = pd.read_csv('Vader_resps_sm1.csv')

# %%
second_sa = pd.read_csv('Vader_resps_sm2.csv')
third_sa = pd.read_csv('Vader_resps_sm3.csv')

# %%
all_sa = pd.concat([first_sa, second_sa, third_sa])

# %%
train_df = train_df.merge(all_sa, on='original_idx')

# %%
train_df.resp_gender.value_counts()
# Out:
# M    4926003
# F    4153796
# U     799217
# Name: resp_gender, dtype: int64

# %%
train_df.head()
# Out:
#    original_idx     op_id op_gender  post_id responder_id  \
# 0             0  57265377         M        0        Jerry
# 1             1  57265377         M        0       Andrea
# 2             2  57265377         M        0       Sherry
# 3             3  57265377         M        0          Bob
# 4             4  57265377         M        0          Joy
#
#                                                                                          response_text  \
# 0  Protecting birth is not the same as protecting life. You may very well pledge to the former but ...
# 1                                                You need to protect children and leave my body to me.
# 2                                                                                            Thank you
# 3                                                                                      Thank you Roger
# 4  Unwanted pregnancy is a sad and unfortunate situation for anyone to find themselves in, however,...
#
#           op_name          op_category  Vader_sent resp_gender
# 0  Roger Williams  Congress_Republican     -0.8483           M
# 1  Roger Williams  Congress_Republican      0.3400           F
# 2  Roger Williams  Congress_Republican      0.3612           F
# 3  Roger Williams  Congress_Republican      0.3612           M
# 4  Roger Williams  Congress_Republican     -0.6660           F

# %%
vectorizer = HashingVectorizer()

# %%
responses = train_df.response_text
xs = []

# we have to do this in chunks because fit_transform
# can't handle the whole thing in memory in string form
for i in range(1,11):
    print("starting chunk {}".format(i))
    chunk = responses.iloc[(i-1)*1000000:i*1000000]
    X = vectorizer.fit_transform(chunk.apply(lambda x: np.str_(x)))
    xs.append(X)
# Out:
# starting chunk 1
# starting chunk 2
# starting chunk 3
# starting chunk 4
# starting chunk 5
# starting chunk 6
# starting chunk 7
# starting chunk 8
# starting chunk 9
# starting chunk 10

# %%
# this is how we recombine the chunks 
X = vstack(xs)

# %%
X.shape
# Out:
# (9879016, 1048576)

# %%
def responder_gender_to_number(row, which):
    if row['resp_gender'] == which:
        return 1
    else:
        return 0
    
train_df['male_ind'] = train_df.apply(responder_gender_to_number, args=('M'), axis=1)

# %%
train_df['female_ind'] = train_df.apply(responder_gender_to_number, args=('F'), axis=1) 
train_df['unknown_ind'] = train_df.apply(responder_gender_to_number, args=('U'), axis=1)

# %%
male_ind_sparse = csr_matrix(train_df.male_ind.values)
female_ind_sparse = csr_matrix(train_df.female_ind.values)
unknown_ind_sparse = csr_matrix(train_df.unknown_ind.values)

# %%
X = hstack([X, male_ind_sparse.T, female_ind_sparse.T, unknown_ind_sparse.T])

# %%
X = hstack([X, csr_matrix(train_df.Vader_sent.values).T])

# %%
Y = train_df.op_gender.values

# %%
model = LogisticRegression(random_state=0)

# %%
time_start = time.time()


model.fit(X,Y)
currentTime = time.gmtime(time.time() - time_start)

#Convert the gmtime struct to a string
timeStr = time.strftime("%M minutes, %S seconds", currentTime)

print("Model trained in {}".format(timeStr))
# Out:
# /home/emilyrapport/anaconda3/envs/w266-env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Model trained in 39 minutes, 14 seconds

# %%
os.mkdir(models_folder + this_model_folder)

# %%
with open(pkl_filename, 'wb') as file:
    pickle.dump(model, file)

# %%
with open(vectorizer_filename, 'wb') as file:
    pickle.dump(vectorizer, file)

# %%
with open(pkl_filename, 'rb') as file:
    model = pickle.load(file)

# %%
dev_df = pd.read_csv(dev_path, index_col=0)
# Out:
# /home/emilyrapport/anaconda3/envs/w266-env/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dev_x = vectorizer.fit_transform(dev_df.response_text.apply(lambda x: np.str_(x)))

# %%
dev_df = dev_df.merge(all_sa, on='original_idx')

# %%
dev_df['male_ind'] = dev_df.apply(responder_gender_to_number, args=('M'), axis=1) 
dev_df['female_ind'] = dev_df.apply(responder_gender_to_number, args=('F'), axis=1) 
dev_df['unknown_ind'] = dev_df.apply(responder_gender_to_number, args=('U'), axis=1)

# %%
dev_male_ind_sparse = csr_matrix(dev_df.male_ind.values)
dev_female_ind_sparse = csr_matrix(dev_df.female_ind.values)
dev_unknown_ind_sparse = csr_matrix(dev_df.unknown_ind.values)

# %%
dev_x = hstack([dev_x, dev_male_ind_sparse.T, dev_female_ind_sparse.T, dev_unknown_ind_sparse.T])
dev_x = hstack([dev_x, csr_matrix(dev_df.Vader_sent.values).T])

# %%
dev_y = dev_df.op_gender.values

# %%
model.score(dev_x, dev_y)
# Out:
# 0.8240827037468157

# %%
preds = model.predict(dev_x)

# %%
probs = model.predict_proba(dev_x)

# %%
probs.shape
# Out:
# (2292907, 2)

# %%
dev_df['preds'] = preds

# %%
prob_m = [prob[0] for prob in probs]
prob_f = [prob[1] for prob in probs]

# %%
dev_df['prob_m'] = prob_m
dev_df['prob_f'] = prob_f

# %%
dev_df.head()
# Out:
#    original_idx     op_id op_gender  post_id responder_id  \
# 0       1965080  86681682         M    29909        James
# 1       1965081  86681682         M    29909       Martha
# 2       1965082  86681682         M    29911      Preston
# 3       1965083  86681682         M    29911        Bobby
# 4       1965084  86681682         M    29911       Landon
#
#                                                                                   response_text  \
# 0  Thanks for passing this ridiculous legislation.  https://www.youtube.com/watch?v=-y4wd8roYrE
# 1                                                       Handsome young man on the left.   😂 mom
# 2                                                                              You're sideways!
# 3                                                                          Hi Congressman Banks
# 4                                        Jim, I love your office. The 5th floor is for winners.
#
#      op_name          op_category  Vader_sent resp_gender  male_ind  \
# 0  Jim Banks  Congress_Republican      0.0065           M         1
# 1  Jim Banks  Congress_Republican      0.4939           F         0
# 2  Jim Banks  Congress_Republican      0.0000           M         1
# 3  Jim Banks  Congress_Republican      0.0000           M         1
# 4  Jim Banks  Congress_Republican      0.8074           M         1
#
#    female_ind  unknown_ind preds    prob_m    prob_f
# 0           0            0     M  0.613098  0.386902
# 1           1            0     M  0.874693  0.125307
# 2           0            0     M  0.628705  0.371295
# 3           0            0     M  0.984654  0.015346
# 4           0            0     M  0.827806  0.172194

# %%
#### get all wrong predictions
wrong_preds = dev_df[dev_df['op_gender']!=dev_df['preds']]

# %%
# even though around 20% of the data set has label W,
# 3/4 of the model's mistakes are on those rows
wrong_preds.op_gender.value_counts()
# Out:
# W    302257
# M    101105
# Name: op_gender, dtype: int64

# %%
# model is only predicting W about 6.7% of the time 
dev_df.preds.value_counts()['W'] / dev_df.preds.value_counts()['M']
# Out:
# 0.06670503176751306

# %%
label_m_pred_f = wrong_preds[wrong_preds.op_gender=='M']

# %%
label_f_pred_m = wrong_preds[wrong_preds.op_gender=='W']

# %%
# wow, fascinating - these are mostly all about planned parenthood 
# or generally about women's reproductive rights 
label_m_pred_f.head(20)
# Out:
#      original_idx     op_id op_gender  post_id responder_id  \
# 39        1965119  86681682         M    29911        Linda
# 49        1965129  86681682         M    29911       Debbie
# 72        1965152  86681682         M    29914       Amanda
# 75        1965155  86681682         M    29914       Sharon
# 76        1965156  86681682         M    29914       Lauren
# 82        1965162  86681682         M    29914      Beverly
# 86        1965166  86681682         M    29914         Leah
# 87        1965167  86681682         M    29914      Desirea
# 93        1965173  86681682         M    29914      William
# 94        1965174  86681682         M    29914        Tandy
# 102       1965182  86681682         M    29914       Jackie
# 103       1965183  86681682         M    29914       Rhonda
# 104       1965184  86681682         M    29914       Rachel
# 107       1965187  86681682         M    29914        Megan
# 109       1965189  86681682         M    29914    Celestial
# 111       1965191  86681682         M    29914        Emily
# 113       1965193  86681682         M    29914        David
# 114       1965194  86681682         M    29914        Susie
# 117       1965197  86681682         M    29914       Judith
# 128       1965208  86681682         M    29914         Mary
#
#                                                                                            response_text  \
# 39   If you repal the ACA and defund Planned Parenthood where will the poor women of this country obt...
# 49                                                                  Will you please find MIA Todd Young?
# 72   You seem confused by facts, so let me enlighten you. Pew research says that the majority of Amer...
# 75   Abortion rates are the lowest since row vs wade. This is largely attributed to the provision of ...
# 76   How I spent my morning. Defending Planned Parenthood. Defending women's access to healthcare. [[...
# 82   The majority of Americans are prochoice, and support PP. They prevent unwanted pregnancies, and ...
# 86   For the areas without community health centers, Planned Parenthood fills in the gaps. I stand wi...
# 87                                                                          I SUPPORT PLANNED PARENTHOOD
# 93   Congressman Banks, I have a bill that could be proposed before the House that would help prevent...
# 94                                                PP provides SAFE CHOICES and so much more .. [[PHOTO]]
# 102                        I stand with Planned Parenthood.  Please stand with your female constituents.
# 103  Why do you lie to your constituents?  Everyone knows that zero tax dollars go to abortion care. ...
# 104  Representative Banks, I am a resident of Fort Wayne, and I support Planned Parenthood.  Tax doll...
# 107  Many supporters were out today FOR Planned Parenthood. A lot of polls actually state people are ...
# 109  Mr. Banks, I support public funding of Planned Parenthood. PP has provided health services to wo...
# 111  And... one more educated republican voter sorely disappointed in this archaic view of what PP do...
# 113  If Mr Banks and others like him were truly interested in stopping abortions then they would have...
# 114  All women deserve health care. Planned Parenthood provides inexpensive health care. It does not ...
# 117  Jim, your statistics are incorrect when it comes to supporters of a woman's right to choose and ...
# 128                 Thank you, Jim Banks for standing up for females. The unborn ones who have no voice.
#
#        op_name          op_category  Vader_sent resp_gender  male_ind  \
# 39   Jim Banks  Congress_Republican      0.5423           F         0
# 49   Jim Banks  Congress_Republican     -0.1613           F         0
# 72   Jim Banks  Congress_Republican     -0.3368           F         0
# 75   Jim Banks  Congress_Republican      0.3612           F         0
# 76   Jim Banks  Congress_Republican      0.0000           F         0
# 82   Jim Banks  Congress_Republican     -0.9027           F         0
# 86   Jim Banks  Congress_Republican     -0.5759           F         0
# 87   Jim Banks  Congress_Republican      0.4019           U         0
# 93   Jim Banks  Congress_Republican      0.9214           M         1
# 94   Jim Banks  Congress_Republican      0.5622           U         0
# 102  Jim Banks  Congress_Republican      0.3182           U         0
# 103  Jim Banks  Congress_Republican      0.7649           F         0
# 104  Jim Banks  Congress_Republican      0.5574           F         0
# 107  Jim Banks  Congress_Republican      0.9402           F         0
# 109  Jim Banks  Congress_Republican      0.6705           U         0
# 111  Jim Banks  Congress_Republican     -0.1945           F         0
# 113  Jim Banks  Congress_Republican      0.7884           M         1
# 114  Jim Banks  Congress_Republican      0.8184           F         0
# 117  Jim Banks  Congress_Republican      0.9382           F         0
# 128  Jim Banks  Congress_Republican      0.0772           F         0
#
#      female_ind  unknown_ind preds    prob_m    prob_f
# 39            1            0     W  0.412991  0.587009
# 49            1            0     W  0.013792  0.986208
# 72            1            0     W  0.409832  0.590168
# 75            1            0     W  0.453790  0.546210
# 76            1            0     W  0.443739  0.556261
# 82            1            0     W  0.427580  0.572420
# 86            1            0     W  0.413486  0.586514
# 87            0            1     W  0.374897  0.625103
# 93            0            0     W  0.374035  0.625965
# 94            0            1     W  0.496846  0.503154
# 102           0            1     W  0.462498  0.537502
# 103           1            0     W  0.422769  0.577231
# 104           1            0     W  0.232369  0.767631
# 107           1            0     W  0.438979  0.561021
# 109           0            1     W  0.198882  0.801118
# 111           1            0     W  0.477089  0.522911
# 113           0            0     W  0.495709  0.504291
# 114           1            0     W  0.430355  0.569645
# 117           1            0     W  0.354936  0.645064
# 128           1            0     W  0.365616  0.634384

# %%
# these seem more random 
label_f_pred_m.head(20)
# Out:
#        original_idx     op_id op_gender  post_id responder_id  \
# 96309       2252167  47977187         W    43581         Pete
# 96310       2252168  47977187         W    43581          Ann
# 96311       2252169  47977187         W    43581         Marc
# 96312       2252170  47977187         W    43581        David
# 96314       2252172  47977187         W    43581      Colleen
# 96315       2252173  47977187         W    43581       Joseph
# 96316       2252174  47977187         W    43581          Ted
# 96317       2252175  47977187         W    43582     Samantha
# 96318       2252176  47977187         W    43582       Joshua
# 96319       2252177  47977187         W    43582         Tony
# 96320       2252178  47977187         W    43582        Laura
# 96321       2252179  47977187         W    43582        Sandy
# 96322       2252180  47977187         W    43582    Gwendolyn
# 96324       2252182  47977187         W    43582         Troy
# 96325       2252183  47977187         W    43582      Barbara
# 96326       2252184  47977187         W    43582          Jan
# 96327       2252185  47977187         W    43582      Barbara
# 96328       2252186  47977187         W    43582        Danny
# 96329       2252187  47977187         W    43582          Bob
# 96330       2252188  47977187         W    43582        Jacki
#
#                                                                                              response_text  \
# 96309                                                                                          What a joke
# 96310  SEN Cortez Masto:  I would appreciate if you would add to your website a way to write our commen...
# 96311                                                                i voted for you please dont us down .
# 96312                                                                                            Persista!
# 96314                                                                                            Thank you
# 96315  As We The People. We Must Not In Anyway Mistreat A Stranger From Another Country. Those Foreigne...
# 96316                                         please keep fighting for us. we need you now more than ever!
# 96317                                                                                           Thank you!
# 96318  Catherine Cortez Masto on the plus side... y'all can do him what obama did to General Petraeus.....
# 96319                                                                       Sessions is an outright racist
# 96320  Jefferson Beauregard Sessions has no place in the Attorney General's office.  His record on civi...
# 96321                                                                                     I agree with you
# 96322                                           Trump is unfit. That's why all of his pics are disastrous!
# 96324                                                                                           Thank you.
# 96325                                                                                            Thank you
# 96326                         Great to oppose Sessions.  Thank you.  But why did you support Ben Carson!??
# 96327                                                                                               Signed
# 96328                                                            Thank you for your leadership Sen.Cortez!
# 96329  He has helped more black people than you lady have ever seen. Did you even listen to the black A...
# 96330  Called your office several times and signed this petition. Thank you for your stance again Senat...
#
#                       op_name          op_category  Vader_sent resp_gender  \
# 96309  Catherine Cortez Masto  Congress_Democratic      0.2960           M
# 96310  Catherine Cortez Masto  Congress_Democratic      0.6808           F
# 96311  Catherine Cortez Masto  Congress_Democratic      0.3182           M
# 96312  Catherine Cortez Masto  Congress_Democratic      0.0000           M
# 96314  Catherine Cortez Masto  Congress_Democratic      0.3612           F
# 96315  Catherine Cortez Masto  Congress_Democratic     -0.9331           M
# 96316  Catherine Cortez Masto  Congress_Democratic     -0.1260           M
# 96317  Catherine Cortez Masto  Congress_Democratic      0.4199           F
# 96318  Catherine Cortez Masto  Congress_Democratic     -0.5423           M
# 96319  Catherine Cortez Masto  Congress_Democratic     -0.6124           M
# 96320  Catherine Cortez Masto  Congress_Democratic      0.0772           F
# 96321  Catherine Cortez Masto  Congress_Democratic      0.3612           F
# 96322  Catherine Cortez Masto  Congress_Democratic     -0.6360           F
# 96324  Catherine Cortez Masto  Congress_Democratic      0.3612           M
# 96325  Catherine Cortez Masto  Congress_Democratic      0.3612           F
# 96326  Catherine Cortez Masto  Congress_Democratic      0.8736           M
# 96327  Catherine Cortez Masto  Congress_Democratic      0.0000           F
# 96328  Catherine Cortez Masto  Congress_Democratic      0.4199           M
# 96329  Catherine Cortez Masto  Congress_Democratic      0.3400           M
# 96330  Catherine Cortez Masto  Congress_Democratic      0.3612           F
#
#        male_ind  female_ind  unknown_ind preds    prob_m    prob_f
# 96309         1           0            0     M  0.773734  0.226266
# 96310         0           1            0     M  0.740188  0.259812
# 96311         1           0            0     M  0.687293  0.312707
# 96312         1           0            0     M  0.745369  0.254631
# 96314         0           1            0     M  0.638145  0.361855
# 96315         1           0            0     M  0.718859  0.281141
# 96316         1           0            0     M  0.584190  0.415810
# 96317         0           1            0     M  0.637812  0.362188
# 96318         1           0            0     M  0.868839  0.131161
# 96319         1           0            0     M  0.562177  0.437823
# 96320         0           1            0     M  0.791537  0.208463
# 96321         0           1            0     M  0.729906  0.270094
# 96322         0           1            0     M  0.715845  0.284155
# 96324         1           0            0     M  0.644483  0.355517
# 96325         0           1            0     M  0.638145  0.361855
# 96326         1           0            0     M  0.642827  0.357173
# 96327         0           1            0     M  0.666178  0.333822
# 96328         1           0            0     M  0.700804  0.299196
# 96329         1           0            0     M  0.559455  0.440545
# 96330         0           1            0     M  0.744850  0.255150
