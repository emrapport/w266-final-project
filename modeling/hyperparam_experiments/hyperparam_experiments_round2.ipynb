# %% [markdown]
# <a href="https://colab.research.google.com/github/emrapport/w266-final-project/blob/master/hyperparam_experiments_round2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# name of subfolder under models/ where trained models should go
MODEL_PREFIX = "emFridayRound2"

hyp_combos = [    
                {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 2,
                'CONV_LAYER_SIZES': [8, 8],
                'FILTER_SIZES': [2, 2],
                'DROPOUT_RATES': [.2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 3,
                'CONV_LAYER_SIZES': [8, 8, 8],
                'FILTER_SIZES': [3, 3, 3],
                'DROPOUT_RATES': [.2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
               {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 4,
                'CONV_LAYER_SIZES': [8, 8, 8, 8],
                'FILTER_SIZES': [2, 2, 2, 2],
                'DROPOUT_RATES': [.2, .2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
               {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 5,
                'CONV_LAYER_SIZES': [8, 8, 8, 8, 8],
                'FILTER_SIZES': [3, 3, 3, 3, 3],
                'DROPOUT_RATES': [.2, .2, .2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 2,
                'CONV_LAYER_SIZES': [32, 32],
                'FILTER_SIZES': [3, 3],
                'DROPOUT_RATES': [.2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 3,
                'CONV_LAYER_SIZES': [32, 32, 32],
                'FILTER_SIZES': [2, 2, 2],
                'DROPOUT_RATES': [.2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
                  {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 2,
                'CONV_LAYER_SIZES': [64, 64],
                'FILTER_SIZES': [2, 2],
                'DROPOUT_RATES': [.2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 3,
                'CONV_LAYER_SIZES': [64, 64, 64],
                'FILTER_SIZES': [3, 3, 3],
                'DROPOUT_RATES': [.2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
                  {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 2,
                'CONV_LAYER_SIZES': [128, 128],
                'FILTER_SIZES': [3, 3],
                'DROPOUT_RATES': [.2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              {'NUM_EPOCHS': 10,
                'BATCH_SIZE': 1000,
                'MAX_SEQUENCE_LENGTH': 20,
                'N_MOST_FREQ_WORDS_TO_KEEP': 5000,
                'MAX_RESPONSES_PER_POST': 50,
                'NUM_LAYERS': 3,
                'CONV_LAYER_SIZES': [128, 128, 128],
                'FILTER_SIZES': [2, 2, 2],
                'DROPOUT_RATES': [.2, .2, .2],
                'FINAL_DENSE_LAYER_SIZE': 10,
                # embed dim needs to map to one of the glove versions: 50, 100, 200, 300 
                'EMBEDDING_DIM': 50,
                'REMOVE_SHORT_RESP_LENGTH':1,
                'SAMPLE_FROM_BEG_AND_END':True},
              
               
                ]

# %%
## check to ensure hyps are in agreement
for hyp_combo in hyp_combos:
  assert hyp_combo['NUM_LAYERS'] == len(hyp_combo['CONV_LAYER_SIZES'])
  assert hyp_combo['NUM_LAYERS'] == len(hyp_combo['FILTER_SIZES'])
  assert hyp_combo['NUM_LAYERS'] == len(hyp_combo['DROPOUT_RATES'])

# %%
## all this stuff just needs to get run one time per notebook
# Set seeds for reproducible results.
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import HashingVectorizer
from keras.preprocessing.sequence import pad_sequences
from scipy.sparse import hstack, vstack
from keras.preprocessing.text import Tokenizer
from tensorflow.keras import Sequential, layers
from keras.utils import plot_model
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import copy
import time
import pickle
# !pip install gcsfs

pd.set_option('max_colwidth', 100)

project_id = 'w266-251323'
import uuid
bucket_name = 'fb-congressional-data/'
from google.colab import auth
auth.authenticate_user()
# !gcloud config set project {project_id}
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from gcsfs) (4.4.1)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (from gcsfs) (0.4.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from gcsfs) (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gcsfs) (2.21.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.6/dist-packages (from gcsfs) (1.4.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib->gcsfs) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (2019.9.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gcsfs) (1.24.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (0.2.7)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (3.1.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.2->gcsfs) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.7)
# Updated property [core/project].

# %%
train_df = pd.read_csv("gs://fb-congressional-data/contraction_expanded_data/train.csv", index_col=0)
dev_df = pd.read_csv("gs://fb-congressional-data/contraction_expanded_data/dev.csv", index_col=0)
# !gsutil cp gs://fb-congressional-data/glove* /tmp/
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Copying gs://fb-congressional-data/glove.6B.100d.txt...
# Copying gs://fb-congressional-data/glove.6B.200d.txt...
# Copying gs://fb-congressional-data/glove.6B.300d.txt...
# Copying gs://fb-congressional-data/glove.6B.50d.txt...
# \ [4 files][  2.1 GiB/  2.1 GiB]   78.2 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://fb-congressional-data/glove.6B.zip...
# / [5 files][  2.9 GiB/  2.9 GiB]   73.7 MiB/s
# Operation completed over 5 objects/2.9 GiB.

# %%
# all the functions go here
def remove_excess_rows_per_post(df, max_per_post):
  num_responses_per_post = df.post_id.value_counts().reset_index()
  num_responses_per_post.columns = ['post_id', 'num_responses']
  
  too_big_posts = num_responses_per_post[num_responses_per_post.num_responses > max_per_post]
  posts_to_sample = too_big_posts.post_id.values
  
  # this gets all the rows for posts we DON'T need to sample 
  new_train_df = df[~df.post_id.isin(posts_to_sample)]
  # this should be true
  assert(len(too_big_posts) + new_train_df.post_id.nunique() == df.post_id.nunique())
  
  too_big_post_rows = df[df.post_id.isin(posts_to_sample)]
  sampled_rows = too_big_post_rows.groupby('post_id').apply(lambda x: x.sample(n=max_per_post)).reset_index(drop=True)
  new_train_df = pd.concat([new_train_df, sampled_rows])
  
  return new_train_df

def get_labels(train_df, test_df, party_label_ind):

  def turn_to_ints(li):
    final_list = []
    for gender in li:
        if gender=='M':
            final_list.append(1)
        else:
            final_list.append(0)
    male = sum(final_list)
    female = len(final_list)-sum(final_list)
    percent_male = sum(final_list)/len(final_list)
    print('total M: {}, total W: {}, percent M: {}'.format(male,female,percent_male))
    return final_list

  def turn_to_ints_party(li):
    final_list = []
    for party in li:
        if party=='Congress_Republican':
            final_list.append(1)
        else:
            final_list.append(0)
    republican = sum(final_list)
    not_repub = len(final_list)-sum(final_list)
    percent_repub = sum(final_list)/len(final_list)
    print('total republican: {}, total not republican: {}, percent republican: {}'.format(republican,not_repub,percent_repub))
    return final_list

  if party_label_ind:

    y_train = train_df.op_category.values
    y_dev = test_df.op_category.values
    print('training set:')
    y_train = turn_to_ints_party(y_train)
    print('dev set:')
    y_dev = turn_to_ints_party(y_dev) 

  else:
    y_train = train_df.op_gender.values
    y_dev = test_df.op_gender.values
    print('training set:')
    y_train = turn_to_ints(y_train)
    print('dev set:')
    y_dev = turn_to_ints(y_dev)

  y_train = np.asarray(y_train)
  y_dev = np.asarray(y_dev)

  return y_train, y_dev

def get_inputs(train_df, 
               test_df, 
               party_train_df,
               party_dev_df,
               n_words_to_keep,
               max_seq_length):
  def get_text_list(init_list):
      sentences = []
      for sentence in init_list:
          if type(sentence) != str:
              sentences.append("")
          else:
              sentences.append(sentence)
      return sentences

  new_sentences_train = get_text_list(train_df.response_text.values)
  new_sentences_test = get_text_list(dev_df.response_text.values)
  party_new_sentences_train = get_text_list(party_train_df.response_text.values)
  party_new_sentences_test = get_text_list(party_dev_df.response_text.values)

  time_start = time.time()

  # this is the default list of filters + apostrophe
  # added because we have dealt with common contractions, so other apostrophes should mostly be possessive 
  tokenizer = Tokenizer(filters='!"\'#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', oov_token='UNK')
  tokenizer.fit_on_texts(new_sentences_train)


  currentTime = time.gmtime(time.time() - time_start)

  #Convert the gmtime struct to a string
  timeStr = time.strftime("%M minutes, %S seconds", currentTime)

  print("Tokenized in {}".format(timeStr))

  # suggestion from this issue: https://github.com/keras-team/keras/issues/8092
  # seems like OOV and num_words don't work correctly by default 
  tokenizer.word_index = {e:i for e,i in tokenizer.word_index.items() 
                              if i <= n_words_to_keep + 1} 
  tokenizer.word_index[tokenizer.oov_token] = n_words_to_keep + 1

  X_train = tokenizer.texts_to_sequences(new_sentences_train)
  X_test = tokenizer.texts_to_sequences(new_sentences_test)
  X_train = pad_sequences(X_train, padding='post', maxlen=max_seq_length)
  X_test = pad_sequences(X_test, padding='post', maxlen=max_seq_length)

  X_train_party = tokenizer.texts_to_sequences(party_new_sentences_train)
  X_test_party = tokenizer.texts_to_sequences(party_new_sentences_test)
  X_train_party = pad_sequences(X_train_party, padding='post', maxlen=max_seq_length)
  X_test_party = pad_sequences(X_test_party, padding='post', maxlen=max_seq_length)
  return X_train, X_test, X_train_party, X_test_party, tokenizer

def create_embedding_matrix(filepath, 
                            word_index, 
                            embedding_dim):
    vocab_size = len(word_index) + 2  # Now we have to add 2 (reserved 0 plus the manual UNK token)
    embedding_matrix = np.zeros((vocab_size, embedding_dim))

    with open(filepath) as f:
        for line in f:
            word, *vector = line.split()
            if word in word_index:
                idx = word_index[word] 
                embedding_matrix[idx] = np.array(
                    vector, dtype=np.float32)[:embedding_dim]

    return embedding_matrix

def make_model(embedding_matrix, 
               max_seq_length,
               num_layers,
               conv_layer_size,
               filter_size,
               dropout_rate,
               final_hidden_dense_size):
  model = Sequential()

  try:
    model.add(layers.Embedding(embedding_matrix.shape[0], embedding_matrix.shape[1], 
                              weights=[embedding_matrix], 
                              input_length=max_seq_length, 
                              trainable=False))
    for i in range(num_layers):
      model.add(layers.Conv1D(conv_layer_size[i], filter_size[i], activation='relu', padding="same"))
      model.add(layers.Dropout(dropout_rate[i]))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(final_hidden_dense_size, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
  except Exception as ex:
    print(ex)
  finally:
    return model

def train_model(model, 
                train_inputs,
                dev_inputs,
                train_labels,
                dev_labels,
                num_epochs,
                batch_size):
  try:
    time_start = time.time()

    history = model.fit(train_inputs, train_labels,
                        epochs=num_epochs,
                        verbose=True,
                        validation_data=(dev_inputs, dev_labels),
                        batch_size=batch_size)

    currentTime = time.gmtime(time.time() - time_start)

    #Convert the gmtime struct to a string
    timeStr = time.strftime("%M minutes, %S seconds", currentTime)

    print("Trained in {}".format(timeStr))

  except Exception as ex:
    print("Exception: {}".format(ex))
    currentTime = time.gmtime(time.time() - time_start)

    #Convert the gmtime struct to a string
    timeStr = time.strftime("%M minutes, %S seconds", currentTime)

    print("Trained in {}".format(timeStr))  
  finally:
    return model

def pred_to_label(row):
  if row['probs'] >= .5:
    return 'M'
  else:
    return 'W'

def pred_to_party_label(row):
  if row['probs2'] >= .5:
    return 'Congress_Republican'
  else:
    return 'Not_Republican'

def remove_short_responses(responses_df,n):
  '''Takes a dataframe that includes a response_text column and removes 
  responses shorter than or equal to n. Returns new dataframe.'''
  responses_df['split_response'] = responses_df['response_text'].str.split()
  mask = (responses_df['split_response'].str.len() > n)
  responses_df = responses_df.loc[mask]
  responses_df = responses_df.drop(columns='split_response', axis = 1)
  return responses_df

def shorten_single_response(series_list,length):
  '''Take a list of strings and a goal max length. Return the goal length list
  taken half from the beginning of the orginal list and half from the end of 
  the original list.'''
  if type(series_list) != float:
    if len(series_list) > length:
      new_list = series_list[:(length//2+length % 2)] + series_list[-length//2:]
      return new_list
    else: 
      return series_list
  else:
    return series_list

def get_beg_end_responses(responses_df,n):
  '''Takes a dataframe that includes a response_text column, creates new
  response_text strings of word length n using the first n/2 words and last n/2
  words of the response_text and returns a new dataframe with the new response_text.'''
  responses_df['split_response'] = responses_df['response_text'].str.split()
  responses_df['short_response'] = responses_df['split_response'].apply(shorten_single_response,args=(n,))
  responses_df['response_text'] = responses_df['short_response'].str.join(' ')
  responses_df = responses_df.drop(columns=['split_response','short_response'], axis=1)
  return responses_df

# %%
# timestamp is shared across all runs
timestamp = time.time()
for i, hyp_dict in enumerate(hyp_combos):
  print("Training Model {}".format(i))
  new_train_df = remove_excess_rows_per_post(train_df, hyp_dict['MAX_RESPONSES_PER_POST'])
  print("Limiting to {} responses per post resulted in {} training rows".format(hyp_dict['MAX_RESPONSES_PER_POST'],new_train_df.shape[0]))
  if hyp_dict['REMOVE_SHORT_RESP_LENGTH'] > 0:
    new_train_df = remove_short_responses(new_train_df,hyp_dict['REMOVE_SHORT_RESP_LENGTH'])
    dev_df =remove_short_responses(dev_df,hyp_dict['REMOVE_SHORT_RESP_LENGTH'])
    print("Removing responses under {} words resulted in {} training rows".format((hyp_dict['REMOVE_SHORT_RESP_LENGTH']+1),new_train_df.shape[0]))
    ######### Add if using test data###########
    # test_df = remove_short_responses(test_df,hyp_dict['REMOVE_SHORT_RESP_LENGTH'])
    ###########################################
  if hyp_dict['SAMPLE_FROM_BEG_AND_END']:
    length = hyp_dict['MAX_SEQUENCE_LENGTH']
    new_train_df = get_beg_end_responses(new_train_df,length)
    dev_df = get_beg_end_responses(dev_df,length)
    ######### Add if using test data###########
    # test_df = get_beg_end_responses(test_df,length)
    ###########################################
    print("Responses include only the first {} and last {} words".format((length//2+length%2),length//2))
  else:
    print("Responses include only the first {} words".format(hyp_dict['MAX_SEQUENCE_LENGTH']))

  new_train_df = new_train_df.sample(frac=1)
  dev_df = dev_df.sample(frac=1)

  party_train_df = new_train_df[new_train_df.op_category!='Congress_Independent']
  party_dev_df = dev_df[dev_df.op_category!='Congress_Independent']

  # get two sets of labels: gender and party
  print("Getting labels")
  y_train_gender, y_dev_gender = get_labels(new_train_df, dev_df, False)
  y_train_party, y_dev_party = get_labels(party_train_df, party_dev_df, True)

  print("Getting inputs")
  X_train, X_test, X_train_party, X_test_party, tokenizer = get_inputs(new_train_df, 
                                                                       dev_df, 
                                                                       party_train_df,
                                                                       party_dev_df,
                                                                       hyp_dict['N_MOST_FREQ_WORDS_TO_KEEP'], 
                                                                       hyp_dict['MAX_SEQUENCE_LENGTH'])
  embedding_matrix = create_embedding_matrix(
                     '/tmp/glove.6B.{}d.txt'.format(hyp_dict['EMBEDDING_DIM']),
                      tokenizer.word_index, hyp_dict['EMBEDDING_DIM'])
  
  # gender model
  model = make_model(embedding_matrix, 
                     hyp_dict['MAX_SEQUENCE_LENGTH'],
                     hyp_dict['NUM_LAYERS'],
                     hyp_dict['CONV_LAYER_SIZES'],
                     hyp_dict['FILTER_SIZES'],
                     hyp_dict['DROPOUT_RATES'],
                     hyp_dict['FINAL_DENSE_LAYER_SIZE'])
  print(model.summary())
  trained_model = train_model(model,
                              X_train,
                              X_test,
                              y_train_gender,
                              y_dev_gender,
                              hyp_dict['NUM_EPOCHS'],
                              hyp_dict['BATCH_SIZE']
                              )
  
  # adding epoch time just in case we accidentally re-use the same prefixes 
  gender_model_path = '{}_model_{}_gender_{}.h5'.format(MODEL_PREFIX, i, timestamp)
  model.save(gender_model_path)
  # !gsutil cp /content/{gender_model_path} gs://fb-congressional-data/models/{gender_model_path}

  preds = model.predict(X_test)
  dev_df['probs'] = preds
  dev_df['preds'] = dev_df.apply(pred_to_label, axis=1)

  if 'W' in dev_df.preds.value_counts():
    proportion_women_predicted = dev_df.preds.value_counts()['W'] / len(dev_df)
  else:
    proportion_women_predicted = 0
  print("Proportion of predictions for W class: {}".format(proportion_women_predicted))
  plt.figure()
  plt.title('Probablities for Gender Prediction, Model {}'.format(i))
  dev_df.probs.hist(bins=20)
  plt.show()

  # party model
  model2 = make_model(embedding_matrix, 
                      hyp_dict['MAX_SEQUENCE_LENGTH'],
                      hyp_dict['NUM_LAYERS'],
                      hyp_dict['CONV_LAYER_SIZES'],
                      hyp_dict['FILTER_SIZES'],
                      hyp_dict['DROPOUT_RATES'],
                      hyp_dict['FINAL_DENSE_LAYER_SIZE'])
  trained_model2 = train_model(model2,
                               X_train_party,
                               X_test_party,
                               y_train_party,
                               y_dev_party,
                               hyp_dict['NUM_EPOCHS'],
                               hyp_dict['BATCH_SIZE'])
  
  party_model_path = '{}_model_{}_party_{}.h5'.format(MODEL_PREFIX, i, timestamp)
  model2.save(party_model_path) # Note: changed this to model2
  # !gsutil cp /content/{party_model_path} gs://fb-congressional-data/models/{party_model_path}

  preds2 = model2.predict(X_test)
  dev_df['probs2'] = preds2
  dev_df['preds2'] = dev_df.apply(pred_to_party_label, axis=1)

  if 'Congress_Republican' in dev_df.preds2.value_counts():
    proportion_republican_predicted = dev_df.preds2.value_counts()['Congress_Republican'] / len(dev_df)
  else:
    proportion_republican_predicted = 0
  print("Proportion of predictions for Republican class: {}".format(proportion_republican_predicted))
  plt.figure()
  plt.title('Probablities for Party Prediction, Model {}'.format(i))
  dev_df.probs2.hist(bins=20)
  plt.show()
# Out:
# Training Model 0
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755947 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2752041, total W: 1003906, percent M: 0.7327156107367863
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2337054, total not republican: 1402563, percent republican: 0.6249447470155366
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 26 seconds
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 50)            250150
# _________________________________________________________________
# conv1d (Conv1D)              (None, 20, 8)             808
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 8)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 20, 8)             136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 8)             0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 10)                90
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 251,195
# Trainable params: 1,045
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755947 samples, validate on 2150792 samples
# Epoch 1/10
# 3755947/3755947 [==============================] - 25s 7us/sample - loss: 0.5324 - acc: 0.7589 - val_loss: 0.4503 - val_acc: 0.8456
# Epoch 2/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5141 - acc: 0.7682 - val_loss: 0.4457 - val_acc: 0.8450
# Epoch 3/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5106 - acc: 0.7701 - val_loss: 0.4461 - val_acc: 0.8460
# Epoch 4/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5091 - acc: 0.7707 - val_loss: 0.4442 - val_acc: 0.8458
# Epoch 5/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5083 - acc: 0.7712 - val_loss: 0.4470 - val_acc: 0.8423
# Epoch 6/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5078 - acc: 0.7712 - val_loss: 0.4441 - val_acc: 0.8461
# Epoch 7/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5074 - acc: 0.7714 - val_loss: 0.4462 - val_acc: 0.8435
# Epoch 8/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5071 - acc: 0.7716 - val_loss: 0.4414 - val_acc: 0.8458
# Epoch 9/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5069 - acc: 0.7717 - val_loss: 0.4520 - val_acc: 0.8372
# Epoch 10/10
# 3755947/3755947 [==============================] - 23s 6us/sample - loss: 0.5067 - acc: 0.7718 - val_loss: 0.4435 - val_acc: 0.8452
# Trained in 03 minutes, 51 seconds
# Copying file:///content/emFridayRound2_model_0_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for W class: 0.033916343374905615
# Train on 3739617 samples, validate on 2150792 samples
# Epoch 1/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.6335 - acc: 0.6464 - val_loss: 0.6124 - val_acc: 0.7070
# Epoch 2/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.6109 - acc: 0.6634 - val_loss: 0.6133 - val_acc: 0.7043
# Epoch 3/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.6035 - acc: 0.6677 - val_loss: 0.6050 - val_acc: 0.7154
# Epoch 4/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5994 - acc: 0.6699 - val_loss: 0.6038 - val_acc: 0.7121
# Epoch 5/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5974 - acc: 0.6708 - val_loss: 0.6026 - val_acc: 0.7125
# Epoch 6/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5962 - acc: 0.6714 - val_loss: 0.6030 - val_acc: 0.7122
# Epoch 7/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5954 - acc: 0.6717 - val_loss: 0.5854 - val_acc: 0.7321
# Epoch 8/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5951 - acc: 0.6718 - val_loss: 0.5932 - val_acc: 0.7207
# Epoch 9/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5946 - acc: 0.6719 - val_loss: 0.5883 - val_acc: 0.7272
# Epoch 10/10
# 3739617/3739617 [==============================] - 23s 6us/sample - loss: 0.5941 - acc: 0.6721 - val_loss: 0.5971 - val_acc: 0.7188
# Trained in 03 minutes, 49 seconds
# Copying file:///content/emFridayRound2_model_0_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for Republican class: 0.9237862145665411
# Training Model 1
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3756032 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751728, total W: 1004304, percent M: 0.7326156965648855
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336966, total not republican: 1402750, percent republican: 0.6249046719055672
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 23 seconds
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 20, 8)             1208
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 8)             0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 20, 8)             200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20, 8)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 20, 8)             200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 20, 8)             0
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 8)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 251,859
# Trainable params: 1,709
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3756032 samples, validate on 2150792 samples
# Epoch 1/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5296 - acc: 0.7609 - val_loss: 0.4538 - val_acc: 0.8484
# Epoch 2/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5097 - acc: 0.7712 - val_loss: 0.4488 - val_acc: 0.8475
# Epoch 3/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5071 - acc: 0.7723 - val_loss: 0.4432 - val_acc: 0.8490
# Epoch 4/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5058 - acc: 0.7728 - val_loss: 0.4414 - val_acc: 0.8501
# Epoch 5/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5052 - acc: 0.7731 - val_loss: 0.4381 - val_acc: 0.8486
# Epoch 6/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5047 - acc: 0.7734 - val_loss: 0.4460 - val_acc: 0.8493
# Epoch 7/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5043 - acc: 0.7736 - val_loss: 0.4410 - val_acc: 0.8509
# Epoch 8/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5041 - acc: 0.7737 - val_loss: 0.4449 - val_acc: 0.8498
# Epoch 9/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5039 - acc: 0.7739 - val_loss: 0.4363 - val_acc: 0.8502
# Epoch 10/10
# 3756032/3756032 [==============================] - 25s 7us/sample - loss: 0.5039 - acc: 0.7737 - val_loss: 0.4400 - val_acc: 0.8490
# Trained in 04 minutes, 10 seconds
# Copying file:///content/emFridayRound2_model_1_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for W class: 0.024821554106580275
# Train on 3739716 samples, validate on 2150792 samples
# Epoch 1/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6372 - acc: 0.6306 - val_loss: 0.6483 - val_acc: 0.6699
# Epoch 2/10
# 3739716/3739716 [==============================] - 24s 7us/sample - loss: 0.6251 - acc: 0.6355 - val_loss: 0.6475 - val_acc: 0.6565
# Epoch 3/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6223 - acc: 0.6376 - val_loss: 0.6434 - val_acc: 0.6629
# Epoch 4/10
# 3739716/3739716 [==============================] - 24s 7us/sample - loss: 0.6210 - acc: 0.6387 - val_loss: 0.6334 - val_acc: 0.6782
# Epoch 5/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6202 - acc: 0.6398 - val_loss: 0.6519 - val_acc: 0.6109
# Epoch 6/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6193 - acc: 0.6412 - val_loss: 0.6496 - val_acc: 0.6347
# Epoch 7/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6187 - acc: 0.6422 - val_loss: 0.6761 - val_acc: 0.5584
# Epoch 8/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6183 - acc: 0.6429 - val_loss: 0.6584 - val_acc: 0.5936
# Epoch 9/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6179 - acc: 0.6434 - val_loss: 0.6607 - val_acc: 0.6113
# Epoch 10/10
# 3739716/3739716 [==============================] - 25s 7us/sample - loss: 0.6177 - acc: 0.6439 - val_loss: 0.6606 - val_acc: 0.5901
# Trained in 04 minutes, 07 seconds
# Copying file:///content/emFridayRound2_model_1_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for Republican class: 0.5654568177675945
# Training Model 2
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755661 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751519, total W: 1004142, percent M: 0.7326324181016338
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336797, total not republican: 1402539, percent republican: 0.6249229809784411
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 21 seconds
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 20, 8)             808
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 20, 8)             136
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 20, 8)             136
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 20, 8)             136
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 8)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 251,467
# Trainable params: 1,317
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755661 samples, validate on 2150792 samples
# Epoch 1/10
# 3755661/3755661 [==============================] - 29s 8us/sample - loss: 0.5626 - acc: 0.7326 - val_loss: 0.4982 - val_acc: 0.8471
# Epoch 2/10
# 3755661/3755661 [==============================] - 28s 7us/sample - loss: 0.5525 - acc: 0.7326 - val_loss: 0.5056 - val_acc: 0.8471
# Epoch 3/10
# 3755661/3755661 [==============================] - 28s 8us/sample - loss: 0.5496 - acc: 0.7326 - val_loss: 0.5131 - val_acc: 0.8471
# Epoch 4/10
# 3755661/3755661 [==============================] - 28s 7us/sample - loss: 0.5484 - acc: 0.7327 - val_loss: 0.5090 - val_acc: 0.8465
# Epoch 5/10
# 3755661/3755661 [==============================] - 28s 7us/sample - loss: 0.5475 - acc: 0.7336 - val_loss: 0.5294 - val_acc: 0.8357
# Epoch 6/10
# 3755661/3755661 [==============================] - 28s 7us/sample - loss: 0.5469 - acc: 0.7356 - val_loss: 0.5339 - val_acc: 0.8253
# Epoch 7/10
# 3755661/3755661 [==============================] - 28s 7us/sample - loss: 0.5453 - acc: 0.7360 - val_loss: 0.5124 - val_acc: 0.8146
# Epoch 8/10
# 3755661/3755661 [==============================] - 28s 8us/sample - loss: 0.5387 - acc: 0.7455 - val_loss: 0.4981 - val_acc: 0.8285
# Epoch 9/10
# 3755661/3755661 [==============================] - 28s 8us/sample - loss: 0.5327 - acc: 0.7516 - val_loss: 0.4908 - val_acc: 0.8324
# Epoch 10/10
# 3755661/3755661 [==============================] - 28s 8us/sample - loss: 0.5300 - acc: 0.7538 - val_loss: 0.4790 - val_acc: 0.8355
# Trained in 04 minutes, 42 seconds
# Copying file:///content/emFridayRound2_model_2_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for W class: 0.047160301879493695
# Train on 3739336 samples, validate on 2150792 samples
# Epoch 1/10
# 3739336/3739336 [==============================] - 28s 8us/sample - loss: 0.6498 - acc: 0.6319 - val_loss: 0.6061 - val_acc: 0.7204
# Epoch 2/10
# 3739336/3739336 [==============================] - 28s 7us/sample - loss: 0.6172 - acc: 0.6584 - val_loss: 0.6084 - val_acc: 0.7140
# Epoch 3/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6099 - acc: 0.6639 - val_loss: 0.6226 - val_acc: 0.7032
# Epoch 4/10
# 3739336/3739336 [==============================] - 28s 7us/sample - loss: 0.6060 - acc: 0.6663 - val_loss: 0.6118 - val_acc: 0.7138
# Epoch 5/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6040 - acc: 0.6677 - val_loss: 0.6199 - val_acc: 0.7092
# Epoch 6/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6023 - acc: 0.6692 - val_loss: 0.6287 - val_acc: 0.7032
# Epoch 7/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6012 - acc: 0.6698 - val_loss: 0.6367 - val_acc: 0.6992
# Epoch 8/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6004 - acc: 0.6701 - val_loss: 0.6408 - val_acc: 0.6957
# Epoch 9/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.6002 - acc: 0.6703 - val_loss: 0.6226 - val_acc: 0.7023
# Epoch 10/10
# 3739336/3739336 [==============================] - 27s 7us/sample - loss: 0.5995 - acc: 0.6706 - val_loss: 0.6272 - val_acc: 0.7017
# Trained in 04 minutes, 33 seconds
# Copying file:///content/emFridayRound2_model_2_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Proportion of predictions for Republican class: 0.9078000104147681
# Training Model 3
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755757 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751500, total W: 1004257, percent M: 0.7326086325606262
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336639, total not republican: 1402802, percent republican: 0.6248631814220361
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 21 seconds
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 20, 8)             1208
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 20, 8)             200
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 20, 8)             200
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 20, 8)             200
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 20, 8)             200
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 20, 8)             0
# _________________________________________________________________
# global_max_pooling1d_6 (Glob (None, 8)                 0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                90
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 252,259
# Trainable params: 2,109
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755757 samples, validate on 2150792 samples
# Epoch 1/10
# 3755757/3755757 [==============================] - 31s 8us/sample - loss: 0.5502 - acc: 0.7419 - val_loss: 0.5013 - val_acc: 0.8323
# Epoch 2/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5216 - acc: 0.7642 - val_loss: 0.4884 - val_acc: 0.8352
# Epoch 3/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5173 - acc: 0.7664 - val_loss: 0.4788 - val_acc: 0.8404
# Epoch 4/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5156 - acc: 0.7671 - val_loss: 0.4733 - val_acc: 0.8452
# Epoch 5/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5142 - acc: 0.7677 - val_loss: 0.4747 - val_acc: 0.8427
# Epoch 6/10
# 3755757/3755757 [==============================] - 31s 8us/sample - loss: 0.5128 - acc: 0.7685 - val_loss: 0.4794 - val_acc: 0.8397
# Epoch 7/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5119 - acc: 0.7690 - val_loss: 0.4776 - val_acc: 0.8416
# Epoch 8/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5110 - acc: 0.7694 - val_loss: 0.4748 - val_acc: 0.8391
# Epoch 9/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5104 - acc: 0.7698 - val_loss: 0.4697 - val_acc: 0.8435
# Epoch 10/10
# 3755757/3755757 [==============================] - 30s 8us/sample - loss: 0.5099 - acc: 0.7701 - val_loss: 0.4789 - val_acc: 0.8412
# Trained in 05 minutes, 04 seconds
# Copying file:///content/emFridayRound2_model_3_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for W class: 0.030387875722059594
# Train on 3739441 samples, validate on 2150792 samples
# Epoch 1/10
# 3739441/3739441 [==============================] - 31s 8us/sample - loss: 0.6512 - acc: 0.6227 - val_loss: 0.6398 - val_acc: 0.7075
# Epoch 2/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6296 - acc: 0.6333 - val_loss: 0.6618 - val_acc: 0.6081
# Epoch 3/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6249 - acc: 0.6367 - val_loss: 0.6548 - val_acc: 0.6234
# Epoch 4/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6230 - acc: 0.6387 - val_loss: 0.6643 - val_acc: 0.5887
# Epoch 5/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6215 - acc: 0.6407 - val_loss: 0.6857 - val_acc: 0.5203
# Epoch 6/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6201 - acc: 0.6424 - val_loss: 0.7004 - val_acc: 0.4916
# Epoch 7/10
# 3739441/3739441 [==============================] - 31s 8us/sample - loss: 0.6191 - acc: 0.6439 - val_loss: 0.7253 - val_acc: 0.4549
# Epoch 8/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6180 - acc: 0.6457 - val_loss: 0.7131 - val_acc: 0.5029
# Epoch 9/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6170 - acc: 0.6472 - val_loss: 0.7471 - val_acc: 0.4324
# Epoch 10/10
# 3739441/3739441 [==============================] - 30s 8us/sample - loss: 0.6163 - acc: 0.6480 - val_loss: 0.7199 - val_acc: 0.4685
# Trained in 05 minutes, 02 seconds
# Copying file:///content/emFridayRound2_model_3_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for Republican class: 0.2979414094900855
# Training Model 4
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755840 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751601, total W: 1004239, percent M: 0.7326193341569396
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336899, total not republican: 1402603, percent republican: 0.6249225164206357
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 22 seconds
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 20, 32)            4832
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 20, 32)            0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 20, 32)            3104
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 20, 32)            0
# _________________________________________________________________
# global_max_pooling1d_8 (Glob (None, 32)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 258,427
# Trainable params: 8,277
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755840 samples, validate on 2150792 samples
# Epoch 1/10
# 3755840/3755840 [==============================] - 26s 7us/sample - loss: 0.5085 - acc: 0.7716 - val_loss: 0.4349 - val_acc: 0.8506
# Epoch 2/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4925 - acc: 0.7785 - val_loss: 0.4369 - val_acc: 0.8477
# Epoch 3/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4890 - acc: 0.7799 - val_loss: 0.4330 - val_acc: 0.8482
# Epoch 4/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4872 - acc: 0.7807 - val_loss: 0.4379 - val_acc: 0.8486
# Epoch 5/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4862 - acc: 0.7811 - val_loss: 0.4411 - val_acc: 0.8459
# Epoch 6/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4853 - acc: 0.7814 - val_loss: 0.4392 - val_acc: 0.8480
# Epoch 7/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4847 - acc: 0.7818 - val_loss: 0.4404 - val_acc: 0.8471
# Epoch 8/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4842 - acc: 0.7820 - val_loss: 0.4322 - val_acc: 0.8476
# Epoch 9/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4839 - acc: 0.7821 - val_loss: 0.4333 - val_acc: 0.8477
# Epoch 10/10
# 3755840/3755840 [==============================] - 25s 7us/sample - loss: 0.4836 - acc: 0.7821 - val_loss: 0.4379 - val_acc: 0.8478
# Trained in 04 minutes, 11 seconds
# Copying file:///content/emFridayRound2_model_4_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for W class: 0.020397137426585183
# Train on 3739502 samples, validate on 2150792 samples
# Epoch 1/10
# 3739502/3739502 [==============================] - 26s 7us/sample - loss: 0.6047 - acc: 0.6664 - val_loss: 0.6054 - val_acc: 0.7133
# Epoch 2/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5749 - acc: 0.6863 - val_loss: 0.6063 - val_acc: 0.7139
# Epoch 3/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5690 - acc: 0.6903 - val_loss: 0.5764 - val_acc: 0.7262
# Epoch 4/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5662 - acc: 0.6923 - val_loss: 0.5875 - val_acc: 0.7227
# Epoch 5/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5646 - acc: 0.6934 - val_loss: 0.5811 - val_acc: 0.7250
# Epoch 6/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5634 - acc: 0.6942 - val_loss: 0.5696 - val_acc: 0.7348
# Epoch 7/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5625 - acc: 0.6948 - val_loss: 0.5784 - val_acc: 0.7302
# Epoch 8/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5618 - acc: 0.6952 - val_loss: 0.5800 - val_acc: 0.7287
# Epoch 9/10
# 3739502/3739502 [==============================] - 26s 7us/sample - loss: 0.5613 - acc: 0.6955 - val_loss: 0.5709 - val_acc: 0.7398
# Epoch 10/10
# 3739502/3739502 [==============================] - 25s 7us/sample - loss: 0.5608 - acc: 0.6960 - val_loss: 0.5758 - val_acc: 0.7355
# Trained in 04 minutes, 13 seconds
# Copying file:///content/emFridayRound2_model_4_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for Republican class: 0.8665380008852553
# Training Model 5
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755593 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751486, total W: 1004107, percent M: 0.7326368964901149
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336645, total not republican: 1402627, percent republican: 0.62489302730585
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 24 seconds
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 20, 32)            3232
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 20, 32)            0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 20, 32)            2080
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 20, 32)            0
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 20, 32)            2080
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 20, 32)            0
# _________________________________________________________________
# global_max_pooling1d_10 (Glo (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 257,883
# Trainable params: 7,733
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755593 samples, validate on 2150792 samples
# Epoch 1/10
# 3755593/3755593 [==============================] - 29s 8us/sample - loss: 0.5127 - acc: 0.7688 - val_loss: 0.4567 - val_acc: 0.8443
# Epoch 2/10
# 3755593/3755593 [==============================] - 28s 7us/sample - loss: 0.4929 - acc: 0.7784 - val_loss: 0.4400 - val_acc: 0.8481
# Epoch 3/10
# 3755593/3755593 [==============================] - 28s 8us/sample - loss: 0.4896 - acc: 0.7797 - val_loss: 0.4511 - val_acc: 0.8455
# Epoch 4/10
# 3755593/3755593 [==============================] - 28s 8us/sample - loss: 0.4881 - acc: 0.7803 - val_loss: 0.4524 - val_acc: 0.8442
# Epoch 5/10
# 3755593/3755593 [==============================] - 28s 8us/sample - loss: 0.4872 - acc: 0.7807 - val_loss: 0.4466 - val_acc: 0.8466
# Epoch 6/10
# 3755593/3755593 [==============================] - 28s 8us/sample - loss: 0.4863 - acc: 0.7810 - val_loss: 0.4473 - val_acc: 0.8468
# Epoch 7/10
# 3755593/3755593 [==============================] - 29s 8us/sample - loss: 0.4858 - acc: 0.7812 - val_loss: 0.4640 - val_acc: 0.8440
# Epoch 8/10
# 3755593/3755593 [==============================] - 29s 8us/sample - loss: 0.4852 - acc: 0.7815 - val_loss: 0.4488 - val_acc: 0.8459
# Epoch 9/10
# 3755593/3755593 [==============================] - 28s 7us/sample - loss: 0.4849 - acc: 0.7817 - val_loss: 0.4427 - val_acc: 0.8431
# Epoch 10/10
# 3755593/3755593 [==============================] - 28s 7us/sample - loss: 0.4847 - acc: 0.7817 - val_loss: 0.4445 - val_acc: 0.8474
# Trained in 04 minutes, 44 seconds
# Copying file:///content/emFridayRound2_model_5_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for W class: 0.024424026126189793
# Train on 3739272 samples, validate on 2150792 samples
# Epoch 1/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.6037 - acc: 0.6665 - val_loss: 0.5688 - val_acc: 0.7449
# Epoch 2/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5757 - acc: 0.6858 - val_loss: 0.5690 - val_acc: 0.7463
# Epoch 3/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5703 - acc: 0.6894 - val_loss: 0.5751 - val_acc: 0.7452
# Epoch 4/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5676 - acc: 0.6910 - val_loss: 0.5656 - val_acc: 0.7483
# Epoch 5/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5658 - acc: 0.6920 - val_loss: 0.5719 - val_acc: 0.7468
# Epoch 6/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5645 - acc: 0.6930 - val_loss: 0.5643 - val_acc: 0.7484
# Epoch 7/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5636 - acc: 0.6935 - val_loss: 0.5596 - val_acc: 0.7496
# Epoch 8/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5628 - acc: 0.6941 - val_loss: 0.5607 - val_acc: 0.7497
# Epoch 9/10
# 3739272/3739272 [==============================] - 28s 8us/sample - loss: 0.5620 - acc: 0.6943 - val_loss: 0.5653 - val_acc: 0.7485
# Epoch 10/10
# 3739272/3739272 [==============================] - 29s 8us/sample - loss: 0.5617 - acc: 0.6946 - val_loss: 0.5767 - val_acc: 0.7480
# Trained in 04 minutes, 48 seconds
# Copying file:///content/emFridayRound2_model_5_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.
# Proportion of predictions for Republican class: 0.8945904578406466
# Training Model 6
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755896 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751586, total W: 1004310, percent M: 0.7326044171617105
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336732, total not republican: 1402828, percent republican: 0.6248681663083357
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 22 seconds
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 20, 64)            6464
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 20, 64)            8256
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# global_max_pooling1d_12 (Glo (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                650
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 265,531
# Trainable params: 15,381
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755896 samples, validate on 2150792 samples
# Epoch 1/10
# 3755896/3755896 [==============================] - 29s 8us/sample - loss: 0.5013 - acc: 0.7747 - val_loss: 0.4459 - val_acc: 0.8478
# Epoch 2/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4854 - acc: 0.7815 - val_loss: 0.4507 - val_acc: 0.8468
# Epoch 3/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4823 - acc: 0.7827 - val_loss: 0.4441 - val_acc: 0.8444
# Epoch 4/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4806 - acc: 0.7833 - val_loss: 0.4496 - val_acc: 0.8449
# Epoch 5/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4795 - acc: 0.7837 - val_loss: 0.4459 - val_acc: 0.8463
# Epoch 6/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4787 - acc: 0.7841 - val_loss: 0.4472 - val_acc: 0.8457
# Epoch 7/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4782 - acc: 0.7842 - val_loss: 0.4537 - val_acc: 0.8442
# Epoch 8/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4777 - acc: 0.7845 - val_loss: 0.4463 - val_acc: 0.8450
# Epoch 9/10
# 3755896/3755896 [==============================] - 27s 7us/sample - loss: 0.4772 - acc: 0.7845 - val_loss: 0.4452 - val_acc: 0.8468
# Epoch 10/10
# 3755896/3755896 [==============================] - 28s 7us/sample - loss: 0.4769 - acc: 0.7846 - val_loss: 0.4393 - val_acc: 0.8464
# Trained in 04 minutes, 39 seconds
# Copying file:///content/emFridayRound2_model_6_gender_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Proportion of predictions for W class: 0.02310869670335393
# Train on 3739560 samples, validate on 2150792 samples
# Epoch 1/10
# 3739560/3739560 [==============================] - 29s 8us/sample - loss: 0.5868 - acc: 0.6794 - val_loss: 0.5838 - val_acc: 0.7307
# Epoch 2/10
# 3739560/3739560 [==============================] - 28s 8us/sample - loss: 0.5596 - acc: 0.6970 - val_loss: 0.5720 - val_acc: 0.7354
# Epoch 3/10
# 3739560/3739560 [==============================] - 28s 7us/sample - loss: 0.5546 - acc: 0.7002 - val_loss: 0.5714 - val_acc: 0.7379
# Epoch 4/10
# 3739560/3739560 [==============================] - 28s 7us/sample - loss: 0.5520 - acc: 0.7016 - val_loss: 0.5673 - val_acc: 0.7464
# Epoch 5/10
# 3739560/3739560 [==============================] - 29s 8us/sample - loss: 0.5504 - acc: 0.7025 - val_loss: 0.5739 - val_acc: 0.7397
# Epoch 6/10
# 3739560/3739560 [==============================] - 28s 8us/sample - loss: 0.5493 - acc: 0.7032 - val_loss: 0.5565 - val_acc: 0.7515
# Epoch 7/10
# 3739560/3739560 [==============================] - 29s 8us/sample - loss: 0.5485 - acc: 0.7037 - val_loss: 0.5672 - val_acc: 0.7434
# Epoch 8/10
# 3739560/3739560 [==============================] - 28s 8us/sample - loss: 0.5479 - acc: 0.7041 - val_loss: 0.5568 - val_acc: 0.7505
# Epoch 9/10
# 3739560/3739560 [==============================] - 28s 8us/sample - loss: 0.5472 - acc: 0.7046 - val_loss: 0.5659 - val_acc: 0.7452
# Epoch 10/10
# 3739560/3739560 [==============================] - 28s 8us/sample - loss: 0.5469 - acc: 0.7048 - val_loss: 0.5640 - val_acc: 0.7457
# Trained in 04 minutes, 44 seconds
# Copying file:///content/emFridayRound2_model_6_party_1574448920.8472505.h5 [Content-Type=application/octet-stream]...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Proportion of predictions for Republican class: 0.8695731618864121
# Training Model 7
# Limiting to 50 responses per post resulted in 3962284 training rows
# Removing responses under 2 words resulted in 3755780 training rows
# Responses include only the first 10 and last 10 words
# Getting labels
# training set:
# total M: 2751609, total W: 1004171, percent M: 0.7326331680769375
# dev set:
# total M: 1821965, total W: 328827, percent M: 0.8471135284118595
# training set:
# total republican: 2336853, total not republican: 1402630, percent republican: 0.6249133904339182
# dev set:
# total republican: 1593280, total not republican: 557512, percent republican: 0.7407875796450796
# Getting inputs
# Tokenized in 01 minutes, 20 seconds
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, 20, 50)            250150
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 20, 64)            9664
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 20, 64)            12352
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 20, 64)            12352
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 20, 64)            0
# _________________________________________________________________
# global_max_pooling1d_14 (Glo (None, 64)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                650
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 285,179
# Trainable params: 35,029
# Non-trainable params: 250,150
# _________________________________________________________________
# None
# Train on 3755780 samples, validate on 2150792 samples
# Epoch 1/10
# 3755780/3755780 [==============================] - 34s 9us/sample - loss: 0.4996 - acc: 0.7754 - val_loss: 0.4397 - val_acc: 0.8510
# Epoch 2/10
# 3755780/3755780 [==============================] - 34s 9us/sample - loss: 0.4849 - acc: 0.7816 - val_loss: 0.4495 - val_acc: 0.8490
# Epoch 3/10
# 3755780/3755780 [==============================] - 33s 9us/sample - loss: 0.4819 - acc: 0.7828 - val_loss: 0.4536 - val_acc: 0.8466
# Epoch 4/10
# 3755780/3755780 [==============================] - 34s 9us/sample - loss: 0.4803 - acc: 0.7834 - val_loss: 0.4473 - val_acc: 0.8500
# Epoch 5/10
# 2267000/3755780 [=================>............] - ETA: 10s - loss: 0.4793 - acc: 0.7839Buffered data was truncated after reaching the output size limit.
