# %%
# questions I have as I think about this more:
# when we do the whole deduplication, we should only be doing that on TRAIN, right?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import HashingVectorizer
from scipy.sparse import hstack, vstack
import pandas as pd
import numpy as np
import copy
import time
import pickle

pd.set_option('max_colwidth', 100)

# %%
splits = "splits_1571429760//"

# %%
data_folder = "data//"
train_path = data_folder + splits + "train.csv"
dev_path = data_folder + splits + "dev.csv"

# %%
pkl_filename = "models//first_model.pkl"
vectorizer_filename = "models//first_vectorizer.pkl"

# %%
train_df = pd.read_csv(train_path, index_col=0)
# Out:
# /home/emilyrapport/anaconda3/envs/w266-env/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
vectorizer = HashingVectorizer()

# %%
responses = train_df.response_text
xs = []

# we have to do this in chunks because fit_transform
# can't handle the whole thing in memory in string form
for i in range(1,11):
    print("starting chunk {}".format(i))
    chunk = responses.iloc[(i-1)*1000000:i*1000000]
    X = vectorizer.fit_transform(chunk.apply(lambda x: np.str_(x)))
    xs.append(X)
# Out:
# starting chunk 1
# starting chunk 2
# starting chunk 3
# starting chunk 4
# starting chunk 5
# starting chunk 6
# starting chunk 7
# starting chunk 8
# starting chunk 9
# starting chunk 10

# %%
# this is how we recombine the chunks 
X = vstack(xs)

# %%
X.shape
# Out:
# (9879016, 1048576)

# %%
Y = train_df.op_gender.values

# %%
model = LogisticRegression(random_state=0)

# %%
time_start = time.time()


model.fit(X,Y)
currentTime = time.gmtime(time.time() - time_start)

#Convert the gmtime struct to a string
timeStr = time.strftime("%M minutes, %S seconds", currentTime)

print("Model trained in {}".format(timeStr))
# Out:
# /home/emilyrapport/anaconda3/envs/w266-env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Model trained in 31 minutes, 08 seconds

# %%
with open(pkl_filename, 'wb') as file:
    pickle.dump(model, file)

# %%
with open(vectorizer_filename, 'wb') as file:
    pickle.dump(vectorizer, file)

# %%
with open(pkl_filename, 'rb') as file:
    model = pickle.load(file)

# %%
dev_df = pd.read_csv(dev_path, index_col=0)
# Out:
# /home/emilyrapport/anaconda3/envs/w266-env/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dev_x = vectorizer.fit_transform(dev_df.response_text.apply(lambda x: np.str_(x)))

# %%
dev_y = dev_df.op_gender.values

# %%
model.score(dev_x, dev_y)
# Out:
# 0.824028187798284

# %%
preds = model.predict(dev_x)

# %%
probs = model.predict_proba(dev_x)

# %%
probs.shape
# Out:
# (2292907, 2)

# %%
dev_df['preds'] = preds

# %%
prob_m = [prob[0] for prob in probs]
prob_f = [prob[1] for prob in probs]

# %%
dev_df['prob_m'] = prob_m
dev_df['prob_f'] = prob_f

# %%
dev_df.head()
# Out:
#    original_idx     op_id op_gender  post_id responder_id  \
# 0       1965080  86681682         M    29909        James
# 1       1965081  86681682         M    29909       Martha
# 2       1965082  86681682         M    29911      Preston
# 3       1965083  86681682         M    29911        Bobby
# 4       1965084  86681682         M    29911       Landon
#
#                                        response_text    op_name  \
# 0  Thanks for passing this ridiculous legislation...  Jim Banks
# 1            Handsome young man on the left.   😂 mom  Jim Banks
# 2                                   You're sideways!  Jim Banks
# 3                               Hi Congressman Banks  Jim Banks
# 4  Jim, I love your office. The 5th floor is for ...  Jim Banks
#
#            op_category preds    prob_m    prob_f
# 0  Congress_Republican     M  0.608282  0.391718
# 1  Congress_Republican     M  0.875024  0.124976
# 2  Congress_Republican     M  0.625179  0.374821
# 3  Congress_Republican     M  0.984224  0.015776
# 4  Congress_Republican     M  0.824908  0.175092

# %%
#### get all wrong predictions
wrong_preds = dev_df[dev_df['op_gender']!=dev_df['preds']]

# %%
# even though around 20% of the data set has label W,
# 3/4 of the model's mistakes are on those rows
wrong_preds.op_gender.value_counts()
# Out:
# W    302271
# M    101216
# Name: op_gender, dtype: int64

# %%
# model is only predicting W about 6.7% of the time 
dev_df.preds.value_counts()['W'] / dev_df.preds.value_counts()['M']
# Out:
# 0.0667531703813018

# %%
label_m_pred_f = wrong_preds[wrong_preds.op_gender=='M']

# %%
label_f_pred_m = wrong_preds[wrong_preds.op_gender=='W']

# %%
# wow, fascinating - these are mostly all about planned parenthood 
# or generally about women's reproductive rights 
label_m_pred_f.head(20)
# Out:
#      original_idx     op_id op_gender  post_id responder_id  \
# 39        1965119  86681682         M    29911        Linda
# 49        1965129  86681682         M    29911       Debbie
# 72        1965152  86681682         M    29914       Amanda
# 75        1965155  86681682         M    29914       Sharon
# 76        1965156  86681682         M    29914       Lauren
# 82        1965162  86681682         M    29914      Beverly
# 86        1965166  86681682         M    29914         Leah
# 87        1965167  86681682         M    29914      Desirea
# 91        1965171  86681682         M    29914      William
# 93        1965173  86681682         M    29914      William
# 102       1965182  86681682         M    29914       Jackie
# 103       1965183  86681682         M    29914       Rhonda
# 104       1965184  86681682         M    29914       Rachel
# 107       1965187  86681682         M    29914        Megan
# 109       1965189  86681682         M    29914    Celestial
# 111       1965191  86681682         M    29914        Emily
# 113       1965193  86681682         M    29914        David
# 114       1965194  86681682         M    29914        Susie
# 117       1965197  86681682         M    29914       Judith
# 128       1965208  86681682         M    29914         Mary
#
#                                          response_text    op_name  \
# 39   If you repal the ACA and defund Planned Parent...  Jim Banks
# 49                Will you please find MIA Todd Young?  Jim Banks
# 72   You seem confused by facts, so let me enlighte...  Jim Banks
# 75   Abortion rates are the lowest since row vs wad...  Jim Banks
# 76   How I spent my morning. Defending Planned Pare...  Jim Banks
# 82   The majority of Americans are prochoice, and s...  Jim Banks
# 86   For the areas without community health centers...  Jim Banks
# 87                        I SUPPORT PLANNED PARENTHOOD  Jim Banks
# 91   Today many Hoosiers are more concerned about t...  Jim Banks
# 93   Congressman Banks, I have a bill that could be...  Jim Banks
# 102  I stand with Planned Parenthood.  Please stand...  Jim Banks
# 103  Why do you lie to your constituents?  Everyone...  Jim Banks
# 104  Representative Banks, I am a resident of Fort ...  Jim Banks
# 107  Many supporters were out today FOR Planned Par...  Jim Banks
# 109  Mr. Banks, I support public funding of Planned...  Jim Banks
# 111  And... one more educated republican voter sore...  Jim Banks
# 113  If Mr Banks and others like him were truly int...  Jim Banks
# 114  All women deserve health care. Planned Parenth...  Jim Banks
# 117  Jim, your statistics are incorrect when it com...  Jim Banks
# 128  Thank you, Jim Banks for standing up for femal...  Jim Banks
#
#              op_category preds    prob_m    prob_f
# 39   Congress_Republican     W  0.415952  0.584048
# 49   Congress_Republican     W  0.013800  0.986200
# 72   Congress_Republican     W  0.408738  0.591262
# 75   Congress_Republican     W  0.458014  0.541986
# 76   Congress_Republican     W  0.444759  0.555241
# 82   Congress_Republican     W  0.425613  0.574387
# 86   Congress_Republican     W  0.411750  0.588250
# 87   Congress_Republican     W  0.397278  0.602722
# 91   Congress_Republican     W  0.499514  0.500486
# 93   Congress_Republican     W  0.371448  0.628552
# 102  Congress_Republican     W  0.485511  0.514489
# 103  Congress_Republican     W  0.428085  0.571915
# 104  Congress_Republican     W  0.233959  0.766041
# 107  Congress_Republican     W  0.442229  0.557771
# 109  Congress_Republican     W  0.214693  0.785307
# 111  Congress_Republican     W  0.477529  0.522471
# 113  Congress_Republican     W  0.491277  0.508723
# 114  Congress_Republican     W  0.432344  0.567656
# 117  Congress_Republican     W  0.356855  0.643145
# 128  Congress_Republican     W  0.366704  0.633296

# %%
# these seem more random 
label_f_pred_m.head(20)
# Out:
#        original_idx     op_id op_gender  post_id responder_id  \
# 96309       2252167  47977187         W    43581         Pete
# 96310       2252168  47977187         W    43581          Ann
# 96311       2252169  47977187         W    43581         Marc
# 96312       2252170  47977187         W    43581        David
# 96314       2252172  47977187         W    43581      Colleen
# 96315       2252173  47977187         W    43581       Joseph
# 96316       2252174  47977187         W    43581          Ted
# 96317       2252175  47977187         W    43582     Samantha
# 96318       2252176  47977187         W    43582       Joshua
# 96319       2252177  47977187         W    43582         Tony
# 96320       2252178  47977187         W    43582        Laura
# 96321       2252179  47977187         W    43582        Sandy
# 96322       2252180  47977187         W    43582    Gwendolyn
# 96324       2252182  47977187         W    43582         Troy
# 96325       2252183  47977187         W    43582      Barbara
# 96326       2252184  47977187         W    43582          Jan
# 96327       2252185  47977187         W    43582      Barbara
# 96328       2252186  47977187         W    43582        Danny
# 96329       2252187  47977187         W    43582          Bob
# 96330       2252188  47977187         W    43582        Jacki
#
#                                            response_text  \
# 96309                                        What a joke
# 96310  SEN Cortez Masto:  I would appreciate if you w...
# 96311              i voted for you please dont us down .
# 96312                                          Persista!
# 96314                                          Thank you
# 96315  As We The People. We Must Not In Anyway Mistre...
# 96316  please keep fighting for us. we need you now m...
# 96317                                         Thank you!
# 96318  Catherine Cortez Masto on the plus side... y'a...
# 96319                     Sessions is an outright racist
# 96320  Jefferson Beauregard Sessions has no place in ...
# 96321                                   I agree with you
# 96322  Trump is unfit. That's why all of his pics are...
# 96324                                         Thank you.
# 96325                                          Thank you
# 96326  Great to oppose Sessions.  Thank you.  But why...
# 2003903      Kirsten Gillibrand  Congress_Democratic     M  0.999985
# 2047217      Kirsten Gillibrand  Congress_Democratic     M  0.999984
# 2120170  Cathy McMorris Rodgers  Congress_Republican     M  0.999981
# 1845101              Anna Eshoo  Congress_Democratic     M  0.999979
# 2136860  Cathy McMorris Rodgers  Congress_Republican     M  0.999978
# 1968553      Kirsten Gillibrand  Congress_Democratic     M  0.999974
# 2002679      Kirsten Gillibrand  Congress_Democratic     M  0.999968
# 1242440   Jaime Herrera Beutler  Congress_Republican     M  0.999965
# 2002750      Kirsten Gillibrand  Congress_Democratic     M  0.999964
# 1981090      Kirsten Gillibrand  Congress_Democratic     M  0.999964
#
#                prob_f
# 2004432  1.379446e-08
# 1981579  6.874396e-08
# 2003909  2.583584e-07
# 1957936  2.583584e-07
# 2119143  3.440580e-07
# 2001015  1.563278e-06
# 2133995  1.795796e-06
# 389197   3.490953e-06
# 1938986  4.067776e-06
# 2002576  4.430485e-06
# 2003903  1.454409e-05
# 2047217  1.609841e-05
# 2120170  1.918114e-05
# 1845101  2.141117e-05
# 2136860  2.159917e-05
# 1968553  2.615215e-05
# 2002679  3.183161e-05
# 1242440  3.539707e-05
# 2002750  3.561066e-05
# 1981090  3.561066e-05

# %%
### how many distinct posts/posters are represented in these wrong sets? compared to the whole thing
### 28,522 posts received at least some wrong answers 
wrong_preds.post_id.value_counts()
# Out:
# 389341    10714
# 399296     8149
# 399295     2093
# 296324     2032
# 389337     1912
#           ...
# 256150        1
# 467504        1
# 402305        1
# 395797        1
# 292078        1
# Name: post_id, Length: 28522, dtype: int64

# %%
wrong_preds.op_name.value_counts()
# Out:
# Kirsten Gillibrand        130715
# Cathy McMorris Rodgers     83279
# Marco Rubio                29859
# Ann Wagner                 25707
# John McCain                12613
#                            ...
# Salud Carbajal                67
# Sander Levin                  62
# Trent Kelly                   52
# Cedric Richmond               47
# Adriano Espaillat             12
# Name: op_name, Length: 61, dtype: int64

# %%
# and there are also 61 total congress people in the whole set...
# which means that we got preds wrong for every congress person 
dev_df.op_name.value_counts()
# Out:
# Marco Rubio               632376
# John McCain               301337
# Kirsten Gillibrand        150081
# Cathy McMorris Rodgers     94169
# Paul Ryan                  93554
#                            ...
# Salud Carbajal               963
# Jim Banks                    774
# Cedric Richmond              694
# Sander Levin                 498
# Adriano Espaillat            138
# Name: op_name, Length: 61, dtype: int64

# %%
# for the top 5 CONGRESSPEOPLE whose responses we got wrong, 
# it looks like for several of them, we got most of our preds wrong
# whereas for others, we only got a few wrong
for problem_poster_id in [86569077, 77234050, 46506154, 23984618, 99469231]:
    percent_wrong = len(wrong_preds[wrong_preds.op_id==problem_poster_id]) / len(dev_df[dev_df.op_id==problem_poster_id])
    print("proportion wrong for {}: {}".format(problem_poster_id, percent_wrong))
# Out:
# proportion wrong for 86569077: 0.870963013306148
# proportion wrong for 77234050: 0.8843568477949219
# proportion wrong for 46506154: 0.047217161941629664
# proportion wrong for 23984618: 0.9305364511691885
# proportion wrong for 99469231: 0.04185679156558936

# %%
# for the top 5 POSTS we got wrong, 
# we generally got a high proportion of responses for a given post wrong 
for problem_post_id in [389341, 399296, 399295, 296324, 389337]:
    percent_wrong = len(wrong_preds[wrong_preds.post_id==problem_post_id]) / len(dev_df[dev_df.post_id==problem_post_id])
    print("proportion wrong for {}: {}".format(problem_post_id, percent_wrong))
# Out:
# proportion wrong for 389341: 0.9582327162150076
# proportion wrong for 399296: 0.8380296174413822
# proportion wrong for 399295: 0.8009950248756219
# proportion wrong for 296324: 0.3650080833483025
# proportion wrong for 389337: 0.9100428367444074

# %%
posts_path = data_folder + "facebook_congress_posts.csv"
posts_df = pd.read_csv(posts_path)

# %%
for problem_post_id in [389341, 399296, 399295, 296324, 389337]:
    given_post = posts_df[posts_df.post_id==problem_post_id]
    print(given_post['post_id'].values[0])
    print(given_post['post_text'].values[0])
    print()
# Out:
# 389341
# A number of you have reached out to me about your concerns with Betsy DeVos's nomination to be Education Secretary. I want to let you know that I share your concerns. I will be voting against her confirmation and I will urge my fellow Senators to do the same. Students, parents and teachers deserve an Education Secretary whose commitment to public education and safe schools will not waver. If public education fails, America fails, and I do not believe Mrs. DeVos shares my commitment to a strong public education system.
#
# 399296
# This week marks the 5th anniversary of #Obamacare being signed into law. Whether it's turned your tax filing into a nightmare, you're facing skyrocketing premiums, or your employer has reduced your work hours, I want to hear about it.   Please share your story with me so that I can better understand the challenges you're facing: http://mcmorris.house.gov/your-story/
#
# 399295
# After five years of #Obamacare, too many Americans are suffering. They deserve to be heard, and today I shared their stories.
#
# 296324
# Visiting with my dear and beloved mother Roberta today, her 102nd birthday!
#
# 389337
# I'm at Battery Park in New York City to stand with advocates, elected leaders and concerned New Yorkers against President Trump's shameful executive order.

# %%
dev_df[dev_df.post_id==389341].sort_values('prob_m', ascending=False)[:20]
# Out:
#          original_idx     op_id op_gender  post_id responder_id  \
# 1923633      10973025  86569077         W   389341        Harry
# 1916326      10965718  86569077         W   389341      Sheldon
# 1923276      10972668  86569077         W   389341     Kristina
# 1919076      10968468  86569077         W   389341          Dan
# 1915774      10965166  86569077         W   389341    Florencia
# 1918220      10967612  86569077         W   389341      Monique
# 1924580      10973972  86569077         W   389341         Rick
# 1920355      10969747  86569077         W   389341        Linda
# 1920323      10969715  86569077         W   389341         Mike
# 1925226      10974618  86569077         W   389341         Mary
# 1915629      10965021  86569077         W   389341    Mamiejane
# 1923939      10973331  86569077         W   389341         Joan
# 1922858      10972250  86569077         W   389341          Ben
# 1923388      10972780  86569077         W   389341         John
# 1916383      10965775  86569077         W   389341        Ellen
# 1916873      10966265  86569077         W   389341         Doug
# 1925281      10974673  86569077         W   389341        Laura
# 1925151      10974543  86569077         W   389341      Patrick
# 1919935      10969327  86569077         W   389341        Robin
